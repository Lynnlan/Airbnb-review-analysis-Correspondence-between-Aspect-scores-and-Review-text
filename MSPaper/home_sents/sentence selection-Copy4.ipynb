# %%
import re
from pandas import Series, DataFrame
import pandas as pd
from numpy.random import randn
import numpy as np
# %matplotlib inline 
import matplotlib.pyplot as plt
import os
import nltk
# use wordnet find the first level keywords
from nltk.corpus import wordnet as wn
import spacy

# %% [markdown]
# *******
# ### Here, the logic of determine the aspect that a sentence talking about is:
#
# * `aspect_keywords_dic` is a dictionary contains aspects and their relevant keywords.
#
# * Firstly, I use the Word2Vec similarity algorithm to count the similarity score between two words.
#
# * For each sentence, the aspect-similarity-score will `+1` when one word in it has the word-similarity-score with any word in keyword list lager than `0.7`(this number can change based on needs).
#
# * I tried use the total scores of all vectors(word-in-sentence to word-in-keywords), however, the results are very strange.

# %%
nlp = spacy.load('en_core_web_md')

# %%
aspect_keywords_dic = {
    'location': ['region', 'locality', 'neck_of_the_woods', 'location', 'vicinity',
                 'neighbourhood', 'neighborhood'],
    'cleanliness': ['tidy_up', 'straighten_out', 'cleanliness', 'clean', 
                    'neaten', 'square_away', 'straighten', 'clean_house', 'make_clean', 
                    'tidy', 'houseclean', 'clean_up', 'scavenge',
                   'soiled', 'unclean', 'colly', 'bemire', 'uncleanliness', 'soil', 'begrime',
                    'grime', 'untidy', 'dirty']
}

def sim_sents(doc, aspect, sim):
    sim_sents = []
    aspect_keywords = nlp(' '.join(aspect_keywords_dic[aspect]))
    
    for which_sen in range(len(list(doc.sents))):
        new_doc = list(doc.sents)[which_sen].text        
        sen_keywords = nlp(new_doc)
        
        if compute_score(sen_keywords, aspect_keywords, sim) > 0:
            sim_sents.append(new_doc)
    
    return sim_sents

def compute_score(sen_keywords, aspect_keywords, sim):
    count = 0
    for token1 in sen_keywords:
        for token2 in aspect_keywords:
            if token1.similarity(token2) >= sim:
                count += 1 
    return count

# %%
def asp_rlt_sents_of_homes(aspect, sample_df):
    
    score_dic = {}
    score_name = 'scores_'+aspect
    score_series = sample_df.groupby(['home_id'])['review_id'].count()
    summary_df = pd.DataFrame(columns=['home_id','num_of_reviews', 'num_of_sents',
                                       'aspect', 'num_of_sents_0.5', 'num_of_sents_0.6', 
                                       'num_of_sents_0.7', 'sents_0.5', 'sents_0.6', 'sents_0.7'])

    for i in range(len(score_series)):
        
        print("home" + str(i+1))
        home_id = score_series.index[i]
        num_of_reviews = score_series.values[i]
        num_of_sents = count_sents(home_id, sample_df)[0]
        num_of_sents_05, sents_05 = home_sents_process(home_id, sample_df, aspect, 0.5)
        num_of_sents_06, sents_06 = home_sents_process(home_id, sample_df, aspect, 0.6)
        num_of_sents_07, sents_07 = home_sents_process(home_id, sample_df, aspect, 0.7)

        summary_df.loc[i] = [home_id, num_of_reviews, num_of_sents, aspect, num_of_sents_05, 
                             num_of_sents_06, num_of_sents_07, sents_05, sents_06, sents_07]

    return summary_df

def count_sents(home_id, sample_df):
    # all comments together
    comments_list = [x for x in list(sample_df[sample_df.home_id == home_id].comments) if isinstance(x, str)]
    comments = ''.join(comments_list)
    doc = nlp(comments)
    
    return len(list(doc.sents)), doc
    
def home_sents_process(home_id, sample_df, aspect, sim):
    doc = count_sents(home_id, sample_df)[1]
#     sents_score_dic = sents_sim_score(doc, aspect, sim)
#     home_asp_sents = sents_score_dic[sents_score_dic['aspect_sim_score'] != 0].text.values
    home_asp_sents = sim_sents(doc, aspect, sim)

    return len(home_asp_sents), home_asp_sents

# %% [markdown]
# ### Let's see the result of homes with different cleanliness score.

# %%
# Load Data: hr means homes&reviews
loc_score7_hr_df = pd.read_csv("../Data/loc_score7_df.csv", sep='\t', encoding="utf-8").drop("Unnamed: 0", axis=1)
print(len(loc_score7_hr_df))

loc_score7_homes_sents = asp_rlt_sents_of_homes('location', loc_score7_hr_df)
loc_score7_homes_sents.to_csv('../Data/loc_hs_df_7.csv', sep='\t', encoding='utf-8')
# Out:
# 164
# home1
# home2
# home3
# home4
# home5
# home6
# home7
# home8
# home9
# home10
# home11
# home12
# home13
# home14
# home15
# home16
# home17
# home18
# home19
# home20
# home21
# home22
# home23
# home24
# home25
# home26
# home27
# home28
#   home_id num_of_reviews num_of_sents    aspect num_of_sents_0.5  \
# 0   23356              5           35  location               15
# 1  190984             51          299  location              142
# 2  613151              4           13  location                5
#
#   num_of_sents_0.6 num_of_sents_0.7  \
# 0                9                7
# 1               57               31
# 2                0                0
#
#                                            sents_0.5  \
# 0  [The neighborhood was a little scary., The hou...
# 1  [We heard from people before our stay that Hil...
# 2  [I rented the lowered floor apartment,  the da...
#
#                                            sents_0.6  \
# 0  [The neighborhood was a little scary., The hou...
# 1  [The bus station to downtown is directly in on...
# 2                                                 []
#
#                                            sents_0.7
# 0  [The neighborhood was a little scary., The hou...
# 1  [The flat was charming and cozy, the location ...
# 2                                                 []

# %%
loc_score7_homes_sents
# Out:
#     home_id num_of_reviews num_of_sents    aspect num_of_sents_0.5  \
# 0     23356              5           35  location               15
# 1    190984             51          299  location              142
# 2    613151              4           13  location                5
# 3   1022135              7           41  location                8
# 4   1263470              6           67  location               22
# 5   1549973              7           43  location               20
# 6   3706719              5           15  location                5
# 7   4041868              6           47  location               16
# 8   4126284              7           40  location               14
# 9   4951079              1           13  location                3
# 10  5104077              3           26  location                6
# 11  5353512              4           25  location                9
# 12  5637990              3           25  location                6
# 13  5792683              4           21  location                5
# 14  6019762              3           22  location                7
# 15  6215199              7           32  location                8
# 16  6250399              1            9  location                6
# 17  6701018             21          103  location               58
# 18  6728017              1            4  location                2
# 19  6959336              3           21  location                8
# 20  7071021              4           41  location               16
# 21  7415378              1            1  location                0
# 22  7839723              1            3  location                0
# 23  7965184              3           13  location                8
# 24  8061699              1            8  location                3
# 25  8083242              3           25  location               11
# 26  9157232              1            6  location                1
# 27  9183838              1           25  location                5
#
#    num_of_sents_0.6 num_of_sents_0.7  \
# 0                 9                7
# 1                57               31
# 2                 0                0
# 3                 5                0
# 4                10                6
# 5                 6                4
# 6                 4                4
# 7                10                4
# 8                 8                3
# 9                 3                1
# 10                5                3
# 11                2                1
# 12                2                2
# 13                3                2
# 14                4                2
# 15                4                4
# 16                1                1
# 17               25               12
# 18                1                1
# 19                3                0
# 20                7                5
# 21                0                0
# 22                0                0
# 23                4                3
# 24                1                0
# 25                8                3
# 26                1                0
# 27                0                0
#
#                                             sents_0.5  \
# 0   [The neighborhood was a little scary., The hou...
# 1   [We heard from people before our stay that Hil...
# 2   [I rented the lowered floor apartment,  the da...
# 3   [Located in North Seattle, with easy access to...
# 4   [My boyfriend and I had the opportunity to sta...
# 5   [The apartment was clean, basic and sufficient...
# 6   [Convenient location, close to shops and the U...
# 7   [The place was perfect for our group(5 guys), ...
# 8   [I was able to come and go as I pleased, which...
# 9   [The kitchen, lounge area and bathroom are sha...
# 10  [geraldine was not in town when we arrived, bu...
# 11  [Anna and her place were great!, Place was nic...
# 12  [The location of the house was perfect for our...
# 13  [The place is the lower floor of a very modern...
# 14  [The bus to downtown is round the corner from ...
# 15  [We visit Seattle every year and the Katt fami...
# 16  [The apartment itself was totally fine - about...
# 17  [This was a great apartment for my family., Af...
# 18  [This house is brand new with all the amenitie...
# 19  [It was about 20 mins from the city.  , Discov...
# 20  [I got stuck in the city without a hotel room ...
# 21                                                 []
# 22                                                 []
# 23  [Great location!  , charming place!  , and I w...
# 24  [There is a big closet with a place for clothe...
# 25  [i am a mother sending son to college  that is...
# 26  [Tania father is very knowledgable about the a...
# 27  [Unfortunately my experience with the Belltown...
#
#                                             sents_0.6  \
# 0   [The neighborhood was a little scary., The hou...
# 1   [The bus station to downtown is directly in on...
# 2                                                  []
# 3   [Located in North Seattle, with easy access to...
# 4   [It was a perfect home away from home as were ...
# 5   [I'm familiar with the neighborhood so new wha...
# 6   [Convenient location, close to shops and the U...
# 7   [The place is about 20 minutes out of downtown...
# 8   [There is a train station only a short walk fr...
# 9   [The kitchen, lounge area and bathroom are sha...
# 10  [the neighborhood is a normal neighborhood, wi...
# 11  [3.The neighborhood: She’s directly across the...
# 12  [The location of the house was perfect for our...
# 13  [The location was nice by a park and centrally...
# 14  [The bus to downtown is round the corner from ...
# 15  [The listing was very accurate and the neighbo...
# 16  [It was very unsettling to know that was so cl...
# 17  [It was located close to a nice park and the z...
# 18  [It is centrally located and a short drive to ...
# 19  [Nikki has a great little house about 12 minut...
# 20  [One of the neighbors tried to teach me how, a...
# 21                                                 []
# 22                                                 []
# 23  [Great location!  , Not sure what happened but...
# 24  [There is a Safeway a block away for groceries...
# 25  [i am a mother sending son to college  that is...
# 26  [Tania father is very knowledgable about the a...
# 27                                                 []
#
#                                             sents_0.7
# 0   [The neighborhood was a little scary., The hou...
# 1   [The flat was charming and cozy, the location ...
# 2                                                  []
# 3                                                  []
# 4   [It was a perfect home away from home as were ...
# 5   [I'm familiar with the neighborhood so new wha...
# 6   [Convenient location, close to shops and the U...
# 7   [The neighborhood is described as an "up and c...
# 8   [It was a little bit of a walk to the train wi...
# 9   [The location is close to several bus routes a...
# 10  [the neighborhood is a normal neighborhood, wi...
# 11  [3.The neighborhood: She’s directly across the...
# 12  [The location of the house was perfect for our...
# 13  [The location was nice by a park and centrally...
# 14  [We found a good breakfast place nearby called...
# 15  [The listing was very accurate and the neighbo...
# 16  [It was very unsettling to know that was so cl...
# 17  [The location was very close to public transpo...
# 18  [It is centrally located and a short drive to ...
# 19                                                 []
# 20  [This was a superb location one block from Uni...
# 21                                                 []
# 22                                                 []
# 23  [Great location!  , Not sure what happened but...
# 24                                                 []
# 25  [but we still stayed in the property for a wee...
# 26                                                 []
# 27                                                 []
